# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
losses = torch.load("/home/avinash/UIUC/CS543/losses.pth")

# %%
plt.plot(list(range(1, 501)), losses)
plt.title("Validation MSE")
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
# Out:
# Text(0, 0.5, 'Mean Squared Error')
